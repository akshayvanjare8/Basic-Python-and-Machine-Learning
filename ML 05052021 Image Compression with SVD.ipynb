# %%
pip install opencv-python

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import cv2 
 
img = cv2.imread("IMG.jpg")
 
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img.shape
# Out:
# (531, 531, 3)

# %%
plt.imshow(img, cmap='Accent')
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap = "gray")
plt.show()

# %%
_,thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, cmap = "gray")
plt.show()

# %%
_,thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)
plt.imshow(thresh, cmap = "gray")
plt.show()

# %%
import numpy as np

# %%
U, S, Vt = np.linalg.svd(gray, full_matrices = False)

# %%
print("Shape of U :", U.shape)
print(U)
print("Shape of S :", S.shape)
print(S)
print("Shape of Vt :", Vt.shape)
print(Vt)
# Out:
# Shape of U : (531, 531)
# [[-1.42984615e-02 -1.83749381e-02 -3.85019673e-02 ... -1.00128257e-12
#   -1.49855530e-12 -1.57001083e-10]
#  [-1.42978734e-02 -1.83730267e-02 -3.85004364e-02 ...  2.10553645e-13
#    1.39403493e-12  1.15313514e-10]
#  [-4.27520817e-02  4.95536773e-02  5.19879627e-03 ... -1.33290288e-13
#   -3.77676098e-14 -2.87443737e-11]
#  ...
#  [-3.37350220e-02  3.37461336e-02 -1.43655031e-02 ... -1.20511240e-14
#   -2.07646400e-14  3.25106782e-12]
#  [-1.46106951e-02 -1.79752785e-02 -3.76426550e-02 ...  6.30114017e-13
#    1.28200402e-13  1.28327197e-11]
#  [-1.44354613e-02 -1.81494804e-02 -3.81627970e-02 ...  1.52075835e-13
#    9.74047232e-15  3.32512178e-11]]
# Shape of S : (531,)
# [1.10901933e+05 1.63261458e+04 1.14357520e+04 7.95271561e+03
#  4.43859068e+03 3.47305657e+03 3.13430434e+03 2.96640069e+03
#  2.08536640e+03 2.05547933e+03 1.88967522e+03 1.77923643e+03
#  1.64769577e+03 1.59894559e+03 1.54499679e+03 1.49153684e+03
# ...

# %%
comps = [U.shape[0],100,50,20,10,5,2,1]
comps
# Out:
# [531, 100, 50, 20, 10, 5, 2, 1]

# %%
fig=plt.figure(figsize=(15,7))
for i in range(len(comps)):
    trans_image=U[:,:comps[i]] @ np.diag(S[:comps[i]]) @ Vt[:comps[i],:]
    plt.subplot(2,4,i+1)
    plt.imshow(trans_image,cmap="gray")
    plt.title("image with n_components "+ str(comps[i]))

# %%
# 64x64=>4094x3=>12288
 
#0 - 255
 
X = np.random.randint(0,256,12288).reshape(64,64,3)
X
# Out:
# array([[[186, 134, 251],
#         [181, 197,   2],
#         [ 71, 228,  75],
#         ...,
#         [ 11,  24,   2],
#         [190,  46,  97],
#         [215,   9, 146]],
#
#        [[151,  71, 181],
#         [105, 216,   3],
#         [164,  23, 155],
#         ...,
#         [216, 204, 100],
#         [ 96, 138,  47],
#         [217,  49, 228]],
#
#        [[126,  27, 132],
#         [148,  36, 116],
#         [ 34,  29,  75],
#         ...,
#         [  8,   3, 157],
#         [231,  90, 223],
#         [117, 128, 220]],
#
#        ...,
#
#        [[ 73, 243, 139],
#         [250, 206, 152],
#         [193, 206, 132],
#         ...,
#         [ 40, 235, 177],
#         [ 17, 198, 227],
#         [244,  70,  29]],
#
#        [[194, 183, 228],
#         [ 99,  16, 119],
#         [217,  60, 227],
#         ...,
#         [ 86, 215,  45],
#         [ 75, 138,  32],
#         [221, 209,   6]],
#
#        [[ 59,  86, 135],
#         [118, 233,  54],
#         [ 96,  22, 104],
# ...

# %%
plt.imshow(X)
plt.show()

# %%
cv2.imwrite("myimage.jpg",X)
# Out:
# True
