# %% [markdown]
# Task 1: Handling missing values
#
# Task 2: Scaling and normalization
#
# Task 3: Parsing dates

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Parsing Dates

# %%
data = pd.read_csv("Building_Permits.csv")
data.head()
# Out:
# /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Number                           198900 non-null  object
#  1   Permit Type                             198900 non-null  int64
#  2   Permit Type Definition                  198900 non-null  object
#  3   Permit Creation Date                    198900 non-null  object
#  4   Block                                   198900 non-null  object
#  5   Lot                                     198900 non-null  object
#  6   Street Number                           198900 non-null  int64
#  7   Street Number Suffix                    2216 non-null    object
#  8   Street Name                             198900 non-null  object
#  9   Street Suffix                           196132 non-null  object
# ...

# %%
data = pd.read_csv("Building_Permits.csv", parse_dates = ["Permit Creation Date", "Current Status Date", "Filed Date", "Issued Date", "Completed Date", "First Construction Document Date"])
data.head()
# Out:
# /data/user/0/ru.iiec.pydroid3/files/aarch64-linux-android/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           2015-05-06  0326  023            140                  NaN
# 1           2016-04-19  0306  007            440                  NaN
# 2           2016-05-27  0595  203           1647                  NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Number                           198900 non-null  object
#  1   Permit Type                             198900 non-null  int64
#  2   Permit Type Definition                  198900 non-null  object
#  3   Permit Creation Date                    198900 non-null  datetime64[ns]
#  4   Block                                   198900 non-null  object
#  5   Lot                                     198900 non-null  object
#  6   Street Number                           198900 non-null  int64
#  7   Street Number Suffix                    2216 non-null    object
#  8   Street Name                             198900 non-null  object
#  9   Street Suffix                           196132 non-null  object
# ...

# %% [markdown]
# #### Missing Values Check

# %%
data.isna().sum()
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
data["Street Number Suffix"] = data["Street Number Suffix"].fillna("U")

data["Street Suffix"] = data["Street Suffix"].fillna("U")

data["Unit"] = data["Unit"].fillna(data["Unit"].mean())

data["Unit Suffix"] = data["Unit Suffix"].fillna("U")

data["Description"] = data["Description"].fillna("U")

data["Issued Date"] = data["Issued Date"].fillna("U")

data["Completed Date"] = data["Completed Date"].fillna("U")

data["First Construction Document Date"] = data["First Construction Document Date"].fillna("U")

data["Structural Notification"] = data["Structural Notification"].fillna("U")

data["Number of Existing Stories"] = data["Number of Existing Stories"].fillna(data["Number of Existing Stories"].mean())

data["Number of Proposed Stories"] = data["Number of Proposed Stories"].fillna(data["Number of Proposed Stories"].mean())

data["Voluntary Soft-Story Retrofit"] = data["Voluntary Soft-Story Retrofit"].fillna("U")

data["Fire Only Permit"] = data["Fire Only Permit"].fillna("U")

data["Permit Expiration Date"] = data["Permit Expiration Date"].fillna("U")

data["Estimated Cost"] = data["Estimated Cost"].fillna(data["Estimated Cost"].mean())

data["Revised Cost"] = data["Revised Cost"].fillna(data["Revised Cost"].mean())

data["Existing Use"] = data["Existing Use"].fillna("U")

data["Existing Units"] = data["Existing Units"].fillna(data["Existing Units"].mean())

data["Proposed Use"] = data["Proposed Use"].fillna("U")

data["Proposed Units"] = data["Proposed Units"].fillna(data["Proposed Units"].mean())

data["Plansets"] = data["Plansets"].fillna(data["Plansets"].mean())

data["TIDF Compliance"] = data["TIDF Compliance"].fillna("U")

#data[""] = data[""].fillna(data[""].mean())

data["Existing Construction Type"] = data["Existing Construction Type"].fillna(data["Existing Construction Type"].mean())

data["Existing Construction Type Description"] = data["Existing Construction Type Description"].fillna("U")

data["Proposed Construction Type"] = data["Proposed Construction Type"].fillna(data["Proposed Construction Type"].mean())

data["Proposed Construction Type Description"] = data["Proposed Construction Type Description"].fillna("U")

data["Site Permit"] = data["Site Permit"].fillna("U")

data["Supervisor District"] = data["Supervisor District"].fillna(data["Supervisor District"].mean())

data["Neighborhoods - Analysis Boundaries"] = data["Neighborhoods - Analysis Boundaries"].fillna("U")

data["Zipcode"] = data["Zipcode"].fillna("U")

data["Location"] = data["Location"].fillna("U")

#data[""] = data[""].fillna(data[""].mean())

# %%
data.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           2015-05-06  0326  023            140                    U
# 1           2016-04-19  0306  007            440                    U
# 2           2016-05-27  0595  203           1647                    U
# 3           2016-11-07  0156  011           1230                    U
# 4           2016-11-28  0342  001            950                    U
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
data.isna().sum()
# Out:
# Permit Number                             0
# Permit Type                               0
# Permit Type Definition                    0
# Permit Creation Date                      0
# Block                                     0
# Lot                                       0
# Street Number                             0
# Street Number Suffix                      0
# Street Name                               0
# Street Suffix                             0
# Unit                                      0
# Unit Suffix                               0
# Description                               0
# Current Status                            0
# Current Status Date                       0
# Filed Date                                0
# Issued Date                               0
# Completed Date                            0
# First Construction Document Date          0
# Structural Notification                   0
# Number of Existing Stories                0
# ...

# %%
data.shape
# Out:
# (198900, 43)

# %%
#data = data.dropna()

#data.isna().sum()

# %%
data.shape
# Out:
# (198900, 43)

# %% [markdown]
# #### Scaling And Normalisation

# %%
data.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           2015-05-06  0326  023            140                    U
# 1           2016-04-19  0306  007            440                    U
# 2           2016-05-27  0595  203           1647                    U
# 3           2016-11-07  0156  011           1230                    U
# 4           2016-11-28  0342  001            950                    U
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
df_num = data[['Unit','Number of Existing Stories', 'Number of Proposed Stories',
       'Estimated Cost', 'Revised Cost', 'Existing Units', 'Proposed Units',
       'Plansets', 'Existing Construction Type', 'Proposed Construction Type',
       'Supervisor District']]
df_num.head()
# Out:
#         Unit  Number of Existing Stories  Number of Proposed Stories  \
# 0  78.517182                         6.0                    5.745043
# 1   0.000000                         7.0                    5.745043
# 2  78.517182                         6.0                    6.000000
# 3   0.000000                         2.0                    2.000000
# 4  78.517182                         3.0                    5.745043
#
#    Estimated Cost   Revised Cost  Existing Units  Proposed Units  Plansets  \
# 0          4000.0    4000.000000      143.000000        16.51095       2.0
# 1             1.0     500.000000       15.666164        16.51095       2.0
# 2         20000.0  132856.186492       39.000000        39.00000       2.0
# 3          2000.0    2000.000000        1.000000         1.00000       2.0
# 4        100000.0  100000.000000       15.666164        16.51095       2.0
#
#    Existing Construction Type  Proposed Construction Type  Supervisor District
# ...

# %%
# data normalization with sklearn
from sklearn.preprocessing import MinMaxScaler

# fit scaler on  data
norm = MinMaxScaler()

norm.fit(df_num)

# transform data
data_norm = norm.transform(df_num)

# %%
data_norm = pd.DataFrame(data_norm)
data_norm.head()
# Out:
#           0         1         2         3             4         5         6  \
# 0  0.013077  0.076923  0.073654  0.000007  5.124920e-06  0.074987  0.008640
# 1  0.000000  0.089744  0.073654  0.000000  6.406150e-07  0.008215  0.008640
# 2  0.013077  0.076923  0.076923  0.000037  1.702193e-04  0.020451  0.020408
# 3  0.000000  0.025641  0.025641  0.000004  2.562460e-06  0.000524  0.000523
# 4  0.013077  0.038462  0.073654  0.000186  1.281230e-04  0.008215  0.008640
#
#           7    8         9   10
# 0  0.000222  0.5  0.772382  0.2
# 1  0.000222  0.5  0.772382  0.2
# 2  0.000222  0.0  0.000000  0.2
# 3  0.000222  1.0  1.000000  0.2
# 4  0.000222  0.5  0.772382  0.5

# %%
# data normalization with sklearn
from sklearn.preprocessing import StandardScaler

# fit scaler on  data
ss = StandardScaler()
ss.fit(df_num)

# transform data
data_ss = ss.transform(df_num)

# %%
data_ss = pd.DataFrame(data_ss)
data_ss.head()
# Out:
#               0         1             2         3         4         5  \
# 0 -2.257853e-16  0.038557  1.164242e-16 -0.050529 -0.036505  1.986331
# 1 -6.237494e-01  0.169601  1.164242e-16 -0.051754 -0.037497  0.000000
# 2 -2.257853e-16  0.038557  3.342033e-02 -0.045628  0.000000  0.363994
# 3 -6.237494e-01 -0.485620 -4.909078e-01 -0.051142 -0.037072 -0.228783
# 4 -2.257853e-16 -0.354576  1.164242e-16 -0.021123 -0.009308  0.000000
#
#           6         7         8         9        10
# 0  0.000000  0.035914 -0.765103  0.000000 -0.883063
# 1  0.000000  0.035914 -0.765103  0.000000 -0.883063
# 2  0.346609  0.035914 -2.191366 -2.211546 -0.883063
# 3 -0.239060  0.035914  0.661160  0.651734 -0.883063
# 4  0.000000  0.035914 -0.765103  0.000000  0.160581
